# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 2.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/9.9 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 1.8/9.9 MB 2.4 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/9.9 MB 2.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.9 MB 2.7 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.9 MB 3.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.9 MB 3.8 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/9.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 4.7 MB/s  0:00:02
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
# ...

# %%
import pandas as pd

# %%
sample=pd.DataFrame({"A":[1,2,3],"B":[4,5,6]})

# %%
# Out:
#    A  B
# 0  1  4
# 1  2  5
